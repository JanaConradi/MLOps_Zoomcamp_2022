# %% [markdown]
# # Module 2 - Tracking an Experiment

# %% [markdown]
# ## Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error

import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

import pyarrow  # read .parquet files
import pickle

import mlflow

# %% [markdown]
# ## Load and preprocess data

# %%
# Tracking with MLFlow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
# Load the data the .parquet file with pandas
df_jan = pd.read_parquet(r"C:\Users\JC\projects\MLOps_Zoomcamp_2022\data\green_tripdata_2021-01.parquet")
df_feb = pd.read_parquet(r"C:\Users\JC\projects\MLOps_Zoomcamp_2022\data\green_tripdata_2021-02.parquet")
df_jan.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4         2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 4         2.0           265           265              3.0           0.00
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0          5.5    0.5      0.5        0.00           0.0      None
# 1         10.0    0.5      0.5        2.81           0.0      None
# 2          6.0    0.5      0.5        1.00           0.0      None
# 3          8.0    0.5      0.5        0.00           0.0      None
# 4        -52.0    0.0     -0.5        0.00           0.0      None
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3          6.80           2.0        1.0
# 1                    0.3         16.86           1.0        1.0
# 2                    0.3          8.30           1.0        1.0
# 3                    0.3          9.30           2.0        1.0
# 4                   -0.3        -52.80           3.0        1.0
#
#    congestion_surcharge
# 0                  0.00
# 1                  2.75
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %%
df_feb.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-02-01 00:34:03   2021-02-01 00:51:58                  N
# 1         2  2021-02-01 00:04:00   2021-02-01 00:10:30                  N
# 2         2  2021-02-01 00:18:51   2021-02-01 00:34:06                  N
# 3         2  2021-02-01 00:53:27   2021-02-01 01:11:41                  N
# 4         2  2021-02-01 00:57:46   2021-02-01 01:06:44                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           130           205              5.0           3.66
# 1         1.0           152           244              1.0           1.10
# 2         1.0           152            48              1.0           4.93
# 3         1.0           152           241              1.0           6.70
# 4         1.0            75            42              1.0           1.89
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0         14.0    0.5      0.5       10.00           0.0      None
# 1          6.5    0.5      0.5        0.00           0.0      None
# 2         16.5    0.5      0.5        0.00           0.0      None
# 3         21.0    0.5      0.5        0.00           0.0      None
# 4          8.5    0.5      0.5        2.45           0.0      None
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3         25.30           1.0        1.0
# 1                    0.3          7.80           2.0        1.0
# 2                    0.3         20.55           2.0        1.0
# 3                    0.3         22.30           2.0        1.0
# 4                    0.3         12.25           1.0        1.0
#
#    congestion_surcharge
# 0                  0.00
# 1                  0.00
# 2                  2.75
# 3                  0.00
# 4                  0.00

# %%
# Preprocessing of the data
# Functionize the read and processing of the dataframe
def read_df(path):
    '''
    Takes in the data, calculates the target variable trip_duration in minutes,
    filters out outlier below 1 min and above 60 min 
    
    Parameters:
    path: path to data in .parquet format
    '''
    # Read the .parquet file
    df = pd.read_parquet(path)

    # Create the target variable
    df["trip_duration"] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.trip_duration = df.trip_duration.apply(lambda x: x.total_seconds() / 60)

    # Extra filter on trip duration from 1 min up to 60 min
    df = df[(df.trip_duration >= 1) & (df.trip_duration <= 60)]
    
    return df

# %%
# Preprocess the data
# Data from January will be the training data
df_train = read_df(r"C:\Users\JC\projects\MLOps_Zoomcamp_2022\data\green_tripdata_2021-01.parquet")

#Data from February will be the validation data
df_val = read_df(r"C:\Users\JC\projects\MLOps_Zoomcamp_2022\data\green_tripdata_2021-02.parquet")

# %%
df_train.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7         2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 7         1.0            75            75              6.0           0.45
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          5.5  ...      0.5        0.00           0.0       None
# 1         10.0  ...      0.5        2.81           0.0       None
# 2          6.0  ...      0.5        1.00           0.0       None
# 3          8.0  ...      0.5        0.00           0.0       None
# 7          3.5  ...      0.5        0.96           0.0       None
#
#   improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                   0.3          6.80           2.0        1.0
# 1                   0.3         16.86           1.0        1.0
# 2                   0.3          8.30           1.0        1.0
# 3                   0.3          9.30           2.0        1.0
# 7                   0.3          5.76           1.0        1.0
#
#    congestion_surcharge  trip_duration
# 0                  0.00       3.933333
# 1                  2.75       8.750000
# 2                  0.00       5.966667
# 3                  0.00       7.083333
# 7                  0.00       2.316667
#
# [5 rows x 21 columns]

# %%
# Function for preprocessing the features (X)
def create_dicts(df, features):
    # Convert to string (object)
    df[features] = df[features].astype(str)
    
    # Convert features to dictionary
    dicts = df[features].to_dict(orient="records")

    return dicts

# %%
# Define the features to predict the target variable
features = ["PULocationID", "DOLocationID"]

# Process the features
feature_dicts_train = create_dicts(df_train, features)

# Create a DictVectorizer
dv = DictVectorizer()

# Fit to the feature dict and save it in a feature matrix
X_train = dv.fit_transform(feature_dicts_train)
y_train = df_train["trip_duration"].values

# Process the features
feature_dicts_val = create_dicts(df_val, features)

# Fit to the feature dict and save it in a feature matrix
X_val = dv.transform(feature_dicts_val)
y_val = df_val["trip_duration"].values

# %% [markdown]
# ## Experiment tracking with MLFlow

# %% [markdown]
# ### A Simple way

# %%
# Connect to MLFLow: Keep track of the history when running a model. 
# A simple way of adding tracking is defining a new run.

with mlflow.start_run():

    mlflow.set_tag("developer", "jana")

    mlflow.log_param("train-data-path", "./data/...")
    mlflow.log_param("valid-data-path", "./data/...")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

# %% [markdown]
# See the results on http://127.0.0.1:5000

# %% [markdown]
# ### Hyperparameter tuning in MLFlow

# %%
# Preprocess the data for XGBoost
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %% [markdown]
# Here, we pass the hyperparameters that are available in XGBoost.

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")

        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, "validation")],
            early_stopping_rounds=25           
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
    return {"loss": rmse, "status": STATUS_OK}

# %% [markdown]
# #### Defining the search space
#
# The search space is the range, in which the hyperparameters shall be optimized. Here, we pass the hyperparameters that are available in XGBoost.

# %%
# Definition of the search space
search_space = {
    "max_depth": scope.int(hp.quniform("max_depth", 4, 100, 1)),
    "learning_rate": hp.loguniform("learning_rate", -3, 0), # range is from exp(-3) and exp(0)
    "reg_alpha": hp.loguniform("reg_alpha", -5, -1),
    "reg_lambda": hp.loguniform("reg_lambda", -6, -1),
    "min_child_weight": hp.loguniform("min_child_weight", -1, 3),
    "objective": "reg:linear",
    "seed": 42
}

# %% [markdown]
# We are using the hyperopt library for hyperparameter optimization. Hyperopt uses Baysian optimization algorithms based on Gaussian processes and regression trees. The default algorithm is Tree of Parzen Estimators (tpe).

# %%
# Defining the function to minimize (fmin)
best_results = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=5,
    trials=Trials()
)
# Out:
# [08:34:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.69525
# [1]	validation-rmse:13.83097
# [2]	validation-rmse:11.99373
# [3]	validation-rmse:10.91671
# [4]	validation-rmse:10.28778
# [5]	validation-rmse:9.74064
# [6]	validation-rmse:9.36773
# [7]	validation-rmse:9.17641
# [8]	validation-rmse:9.02631
# [9]	validation-rmse:8.92391
# [10]	validation-rmse:8.65274
# [11]	validation-rmse:8.57871
# [12]	validation-rmse:8.46490
# [13]	validation-rmse:8.41398
# [14]	validation-rmse:8.37095
# [15]	validation-rmse:8.32479
# [16]	validation-rmse:8.28345
# [17]	validation-rmse:8.25660
# [18]	validation-rmse:8.22479
# [19]	validation-rmse:8.12420
# [20]	validation-rmse:8.08232
# [21]	validation-rmse:8.05413
# [22]	validation-rmse:8.02515
# [23]	validation-rmse:7.98288
# [24]	validation-rmse:7.92668
# [25]	validation-rmse:7.91222
# [26]	validation-rmse:7.87470
# [27]	validation-rmse:7.84327
# [28]	validation-rmse:7.83178
# [29]	validation-rmse:7.80720
# [30]	validation-rmse:7.77211
# [31]	validation-rmse:7.75781
# [32]	validation-rmse:7.74361
# [33]	validation-rmse:7.73728
# [34]	validation-rmse:7.72931
# [35]	validation-rmse:7.71524
# [36]	validation-rmse:7.70814
# [37]	validation-rmse:7.70285
# [38]	validation-rmse:7.68563
# [39]	validation-rmse:7.68416
# [40]	validation-rmse:7.66407
# [41]	validation-rmse:7.66061
# [42]	validation-rmse:7.65165
# [43]	validation-rmse:7.64889
# [44]	validation-rmse:7.63836
# [45]	validation-rmse:7.63441
# [46]	validation-rmse:7.63397
# [47]	validation-rmse:7.63077
# [48]	validation-rmse:7.62658
# [49]	validation-rmse:7.61252
# [50]	validation-rmse:7.60855
# [51]	validation-rmse:7.60728
# [52]	validation-rmse:7.59129
# [53]	validation-rmse:7.58818
# [54]	validation-rmse:7.58626
# [55]	validation-rmse:7.58248
# [56]	validation-rmse:7.58046
# [57]	validation-rmse:7.57763
# [58]	validation-rmse:7.57672
# [59]	validation-rmse:7.57439
# [60]	validation-rmse:7.57281
# [61]	validation-rmse:7.57095
# [62]	validation-rmse:7.57071
# [63]	validation-rmse:7.56745
# [64]	validation-rmse:7.56700
# [65]	validation-rmse:7.56197
# [66]	validation-rmse:7.55834
# [67]	validation-rmse:7.55773
# [68]	validation-rmse:7.55707
# [69]	validation-rmse:7.55532
# [70]	validation-rmse:7.55332
# [71]	validation-rmse:7.55163
# [72]	validation-rmse:7.54993
# [73]	validation-rmse:7.54795
# [74]	validation-rmse:7.54785
# [75]	validation-rmse:7.54619
# [76]	validation-rmse:7.54452
# [77]	validation-rmse:7.54384
# [78]	validation-rmse:7.54358
# [79]	validation-rmse:7.54323
# [80]	validation-rmse:7.54341
# [81]	validation-rmse:7.54272
# [82]	validation-rmse:7.54179
# [83]	validation-rmse:7.54209
# [84]	validation-rmse:7.54108
# [85]	validation-rmse:7.54075
# [86]	validation-rmse:7.53999
# [87]	validation-rmse:7.53957
# [88]	validation-rmse:7.53874
# [89]	validation-rmse:7.53722
# [90]	validation-rmse:7.53710
# [91]	validation-rmse:7.53694
# [92]	validation-rmse:7.53564
# [93]	validation-rmse:7.53585
# [94]	validation-rmse:7.53515
# [95]	validation-rmse:7.53470
# [96]	validation-rmse:7.53388
# [97]	validation-rmse:7.53338
# [98]	validation-rmse:7.53378
# [99]	validation-rmse:7.53319
# [08:35:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.26008
# [1]	validation-rmse:14.60851
# [2]	validation-rmse:12.84745
# [3]	validation-rmse:11.69606
# [4]	validation-rmse:10.99163
# [5]	validation-rmse:10.43908
# [6]	validation-rmse:10.13225
# [7]	validation-rmse:9.86129
# [8]	validation-rmse:9.73360
# [9]	validation-rmse:9.59962
# [10]	validation-rmse:9.50545
# [11]	validation-rmse:9.41251
# [12]	validation-rmse:9.36006
# [13]	validation-rmse:9.31997
# [14]	validation-rmse:9.27517
# [15]	validation-rmse:9.22501
# [16]	validation-rmse:9.19512
# [17]	validation-rmse:9.13882
# [18]	validation-rmse:9.03798
# [19]	validation-rmse:9.02466
# [20]	validation-rmse:9.00588
# [21]	validation-rmse:8.96249
# [22]	validation-rmse:8.93119
# [23]	validation-rmse:8.91629
# [24]	validation-rmse:8.88384
# [25]	validation-rmse:8.85085
# [26]	validation-rmse:8.83709
# [27]	validation-rmse:8.82687
# [28]	validation-rmse:8.81383
# [29]	validation-rmse:8.79559
# [30]	validation-rmse:8.77678
# [31]	validation-rmse:8.75155
# [32]	validation-rmse:8.74441
# [33]	validation-rmse:8.69694
# [34]	validation-rmse:8.68647
# [35]	validation-rmse:8.67907
# [36]	validation-rmse:8.66586
# [37]	validation-rmse:8.65782
# [38]	validation-rmse:8.64529
# [39]	validation-rmse:8.59433
# [40]	validation-rmse:8.58381
# [41]	validation-rmse:8.57374
# [42]	validation-rmse:8.56532
# [43]	validation-rmse:8.55933
# [44]	validation-rmse:8.55482
# [45]	validation-rmse:8.54236
# [46]	validation-rmse:8.53926
# [47]	validation-rmse:8.53189
# [48]	validation-rmse:8.52760
# [49]	validation-rmse:8.52228
# [50]	validation-rmse:8.51654
# [51]	validation-rmse:8.51265
# [52]	validation-rmse:8.49693
# [53]	validation-rmse:8.48573
# [54]	validation-rmse:8.47841
# [55]	validation-rmse:8.47101
# [56]	validation-rmse:8.46765
# [57]	validation-rmse:8.46248
# [58]	validation-rmse:8.45936
# [59]	validation-rmse:8.45435
# [60]	validation-rmse:8.45085
# [61]	validation-rmse:8.44738
# [62]	validation-rmse:8.44181
# [63]	validation-rmse:8.43464
# [64]	validation-rmse:8.42816
# [65]	validation-rmse:8.42456
# [66]	validation-rmse:8.41874
# [67]	validation-rmse:8.41445
# [68]	validation-rmse:8.41100
# [69]	validation-rmse:8.40464
# [70]	validation-rmse:8.39775
# [71]	validation-rmse:8.39434
# [72]	validation-rmse:8.39002
# [73]	validation-rmse:8.38745
# [74]	validation-rmse:8.38348
# [75]	validation-rmse:8.38064
# [76]	validation-rmse:8.37712
# [77]	validation-rmse:8.37553
# [78]	validation-rmse:8.37105
# [79]	validation-rmse:8.36798
# [80]	validation-rmse:8.36545
# [81]	validation-rmse:8.36055
# [82]	validation-rmse:8.35644
# [83]	validation-rmse:8.35405
# [84]	validation-rmse:8.34925
# [85]	validation-rmse:8.34718
# [86]	validation-rmse:8.34309
# [87]	validation-rmse:8.33941
# [88]	validation-rmse:8.33745
# [89]	validation-rmse:8.33374
# [90]	validation-rmse:8.32965
# [91]	validation-rmse:8.32523
# [92]	validation-rmse:8.32279
# [93]	validation-rmse:8.31884
# [94]	validation-rmse:8.31602
# [95]	validation-rmse:8.31046
# [96]	validation-rmse:8.30714
# [97]	validation-rmse:8.30476
# [98]	validation-rmse:8.30180
# [99]	validation-rmse:8.30004
# [08:35:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.88154
# [1]	validation-rmse:18.70715
# [2]	validation-rmse:17.65168
# [3]	validation-rmse:16.69574
# [4]	validation-rmse:15.83725
# [5]	validation-rmse:15.08444
# [6]	validation-rmse:14.39940
# [7]	validation-rmse:13.79349
# [8]	validation-rmse:13.26532
# [9]	validation-rmse:12.79156
# [10]	validation-rmse:12.36938
# [11]	validation-rmse:12.00549
# [12]	validation-rmse:11.66568
# [13]	validation-rmse:11.35816
# [14]	validation-rmse:11.10305
# [15]	validation-rmse:10.88319
# [16]	validation-rmse:10.68822
# [17]	validation-rmse:10.49216
# [18]	validation-rmse:10.32205
# [19]	validation-rmse:10.19058
# [20]	validation-rmse:10.06741
# [21]	validation-rmse:9.96527
# [22]	validation-rmse:9.85348
# [23]	validation-rmse:9.76502
# [24]	validation-rmse:9.67498
# [25]	validation-rmse:9.59703
# [26]	validation-rmse:9.53312
# [27]	validation-rmse:9.46673
# [28]	validation-rmse:9.41288
# [29]	validation-rmse:9.36386
# [30]	validation-rmse:9.32269
# [31]	validation-rmse:9.28472
# [32]	validation-rmse:9.24079
# [33]	validation-rmse:9.20436
# [34]	validation-rmse:9.17619
# [35]	validation-rmse:9.14991
# [36]	validation-rmse:9.12765
# [37]	validation-rmse:9.10761
# [38]	validation-rmse:9.08694
# [39]	validation-rmse:9.06468
# [40]	validation-rmse:9.03990
# [41]	validation-rmse:9.02429
# [42]	validation-rmse:9.00134
# [43]	validation-rmse:8.98489
# [44]	validation-rmse:8.96919
# [45]	validation-rmse:8.95492
# [46]	validation-rmse:8.94146
# [47]	validation-rmse:8.93100
# [48]	validation-rmse:8.91308
# [49]	validation-rmse:8.90108
# [50]	validation-rmse:8.88714
# [51]	validation-rmse:8.87506
# [52]	validation-rmse:8.86241
# [53]	validation-rmse:8.85036
# [54]	validation-rmse:8.84259
# [55]	validation-rmse:8.83181
# [56]	validation-rmse:8.82345
# [57]	validation-rmse:8.81537
# [58]	validation-rmse:8.80749
# [59]	validation-rmse:8.79904
# [60]	validation-rmse:8.79089
# [61]	validation-rmse:8.78303
# [62]	validation-rmse:8.77334
# [63]	validation-rmse:8.76618
# [64]	validation-rmse:8.75804
# [65]	validation-rmse:8.75034
# [66]	validation-rmse:8.74368
# [67]	validation-rmse:8.73630
# [68]	validation-rmse:8.72850
# [69]	validation-rmse:8.71997
# [70]	validation-rmse:8.71322
# [71]	validation-rmse:8.70552
# [72]	validation-rmse:8.69934
# [73]	validation-rmse:8.69323
# [74]	validation-rmse:8.68669
# [75]	validation-rmse:8.67949
# [76]	validation-rmse:8.67417
# [77]	validation-rmse:8.66860
# [78]	validation-rmse:8.66178
# [79]	validation-rmse:8.65579
# [80]	validation-rmse:8.64967
# [81]	validation-rmse:8.64398
# [82]	validation-rmse:8.63651
# [83]	validation-rmse:8.63095
# [84]	validation-rmse:8.62573
# [85]	validation-rmse:8.61566
# [86]	validation-rmse:8.60903
# [87]	validation-rmse:8.60316
# [88]	validation-rmse:8.59640
# [89]	validation-rmse:8.59216
# [90]	validation-rmse:8.58571
# [91]	validation-rmse:8.57921
# [92]	validation-rmse:8.57456
# [93]	validation-rmse:8.56843
# [94]	validation-rmse:8.56270
# [95]	validation-rmse:8.55514
# [96]	validation-rmse:8.55027
# [97]	validation-rmse:8.54409
# [98]	validation-rmse:8.53747
# [99]	validation-rmse:8.53226
# [08:35:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.15720
# [1]	validation-rmse:12.01643
# [2]	validation-rmse:10.30390
# [3]	validation-rmse:9.54012
# [4]	validation-rmse:9.06837
# [5]	validation-rmse:8.75369
# [6]	validation-rmse:8.54582
# [7]	validation-rmse:8.41143
# [8]	validation-rmse:8.19803
# [9]	validation-rmse:8.12226
# [10]	validation-rmse:8.05751
# [11]	validation-rmse:7.96747
# [12]	validation-rmse:7.85433
# [13]	validation-rmse:7.80065
# [14]	validation-rmse:7.78326
# [15]	validation-rmse:7.75817
# [16]	validation-rmse:7.71609
# [17]	validation-rmse:7.70533
# [18]	validation-rmse:7.67923
# [19]	validation-rmse:7.66875
# [20]	validation-rmse:7.65273
# [21]	validation-rmse:7.63595
# [22]	validation-rmse:7.62879
# [23]	validation-rmse:7.62237
# [24]	validation-rmse:7.60350
# [25]	validation-rmse:7.60237
# [26]	validation-rmse:7.60019
# [27]	validation-rmse:7.59512
# [28]	validation-rmse:7.58989
# [29]	validation-rmse:7.58486
# [30]	validation-rmse:7.58454
# [31]	validation-rmse:7.58512
# [32]	validation-rmse:7.58544
# [33]	validation-rmse:7.58536
# [34]	validation-rmse:7.58418
# [35]	validation-rmse:7.58473
# [36]	validation-rmse:7.58283
# [37]	validation-rmse:7.58365
# [38]	validation-rmse:7.58269
# [39]	validation-rmse:7.57935
# [40]	validation-rmse:7.57912
# [41]	validation-rmse:7.57920
# [42]	validation-rmse:7.57994
# [43]	validation-rmse:7.57998
# [44]	validation-rmse:7.58047
# [45]	validation-rmse:7.58036
# [46]	validation-rmse:7.58015
# [47]	validation-rmse:7.58014
# [48]	validation-rmse:7.58073
# [49]	validation-rmse:7.58083
# [50]	validation-rmse:7.58061
# [51]	validation-rmse:7.58058
# [52]	validation-rmse:7.58015
# [53]	validation-rmse:7.58054
# [54]	validation-rmse:7.58104
# [55]	validation-rmse:7.58149
# [56]	validation-rmse:7.58158
# [57]	validation-rmse:7.58223
# [58]	validation-rmse:7.58226
# [59]	validation-rmse:7.58239
# [60]	validation-rmse:7.58254
# [61]	validation-rmse:7.58217
# [62]	validation-rmse:7.58191
# [63]	validation-rmse:7.58199
# [64]	validation-rmse:7.58206
# [65]	validation-rmse:7.58200
# [08:36:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.21008
# [1]	validation-rmse:11.96441
# [2]	validation-rmse:10.30629
# [3]	validation-rmse:9.52358
# [4]	validation-rmse:8.92702
# [5]	validation-rmse:8.68885
# [6]	validation-rmse:8.45796
# [7]	validation-rmse:8.30992
# [8]	validation-rmse:8.19262
# [9]	validation-rmse:8.10092
# [10]	validation-rmse:8.02743
# [11]	validation-rmse:7.96601
# [12]	validation-rmse:7.89609
# [13]	validation-rmse:7.84209
# [14]	validation-rmse:7.79532
# [15]	validation-rmse:7.77007
# [16]	validation-rmse:7.74577
# [17]	validation-rmse:7.71932
# [18]	validation-rmse:7.67236
# [19]	validation-rmse:7.66303
# [20]	validation-rmse:7.63391
# [21]	validation-rmse:7.60215
# [22]	validation-rmse:7.58748
# [23]	validation-rmse:7.56474
# [24]	validation-rmse:7.55627
# [25]	validation-rmse:7.55345
# [26]	validation-rmse:7.54478
# [27]	validation-rmse:7.53962
# [28]	validation-rmse:7.53729
# [29]	validation-rmse:7.53822
# [30]	validation-rmse:7.52944
# [31]	validation-rmse:7.52623
# [32]	validation-rmse:7.52438
# [33]	validation-rmse:7.52300
# [34]	validation-rmse:7.52130
# [35]	validation-rmse:7.52312
# [36]	validation-rmse:7.52025
# [37]	validation-rmse:7.51131
# [38]	validation-rmse:7.50991
# [39]	validation-rmse:7.50751
# [40]	validation-rmse:7.50713
# [41]	validation-rmse:7.50566
# [42]	validation-rmse:7.50528
# [43]	validation-rmse:7.50393
# [44]	validation-rmse:7.50305
# [45]	validation-rmse:7.50043
# [46]	validation-rmse:7.49815
# [47]	validation-rmse:7.49807
# [48]	validation-rmse:7.49710
# [49]	validation-rmse:7.49580
# [50]	validation-rmse:7.49537
# [51]	validation-rmse:7.49701
# [52]	validation-rmse:7.49392
# [53]	validation-rmse:7.49241
# [54]	validation-rmse:7.49050
# [55]	validation-rmse:7.48932
# [56]	validation-rmse:7.48787
# [57]	validation-rmse:7.48696
# [58]	validation-rmse:7.48586
# [59]	validation-rmse:7.48494
# [60]	validation-rmse:7.48403
# [61]	validation-rmse:7.48238
# [62]	validation-rmse:7.48185
# [63]	validation-rmse:7.48014
# [64]	validation-rmse:7.47946
# [65]	validation-rmse:7.47673
# [66]	validation-rmse:7.47707
# [67]	validation-rmse:7.47596
# [68]	validation-rmse:7.47527
# [69]	validation-rmse:7.47363
# [70]	validation-rmse:7.47218
# [71]	validation-rmse:7.47102
# [72]	validation-rmse:7.47126
# [73]	validation-rmse:7.47059
# [74]	validation-rmse:7.46839
# [75]	validation-rmse:7.46748
# [76]	validation-rmse:7.46739
# [77]	validation-rmse:7.46673
# [78]	validation-rmse:7.46400
# [79]	validation-rmse:7.46391
# [80]	validation-rmse:7.46295
# [81]	validation-rmse:7.46131
# [82]	validation-rmse:7.46108
# [83]	validation-rmse:7.45986
# [84]	validation-rmse:7.45929
# [85]	validation-rmse:7.45905
# [86]	validation-rmse:7.45869
# [87]	validation-rmse:7.45858
# [88]	validation-rmse:7.45950
# [89]	validation-rmse:7.45835
# [90]	validation-rmse:7.45872
# [91]	validation-rmse:7.45694
# [92]	validation-rmse:7.45739
# [93]	validation-rmse:7.45698
# [94]	validation-rmse:7.45571
# [95]	validation-rmse:7.45574
# [96]	validation-rmse:7.45407
# [97]	validation-rmse:7.45330
# [98]	validation-rmse:7.45423
# [99]	validation-rmse:7.45339
# 100%|██████████| 5/5 [02:06<00:00, 25.29s/trial, best loss: 7.453385022865575]

# %% [markdown]
# ### Automatic logging (autolog)
#
# Autolog allows to log metrics, params and model without explicit log statements. Whether you use it as a statement before your training code or you can use library-specific calls (available for scikit-learn, Tensorflow, XGBoost etc.)
#
# ```
# mlflow_autolog()
# ```
#
#
# Now, we train a model with the best params found in the hyperparameter optimization and use autolog.

# %%
# Best hyperparameters from training
best_params = {
    "learning_rate": 0.39620689794623454,
    "max_depth": 67,
    "min_child_weight": 2.7580783277428704,
    "objective": "reg:linear",
    "reg_alpha": 0.05148549288379137,
    "reg_lambda": 0.2048884681763893,
    "seed": 42
}

# %%
# Calling autolog for XGBoost
mlflow.xgboost.autolog()

# Train the model
booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, "validation")],
        early_stopping_rounds=25           
        )
# Out:
# 2022/06/01 09:32:15 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b1f59010eedd4c9e8715fc284cf225d7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [09:32:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.21008
# [1]	validation-rmse:11.96441
# [2]	validation-rmse:10.30629
# [3]	validation-rmse:9.52358
# [4]	validation-rmse:8.92702
# [5]	validation-rmse:8.68885
# [6]	validation-rmse:8.45796
# [7]	validation-rmse:8.30992
# [8]	validation-rmse:8.19262
# [9]	validation-rmse:8.10092
# [10]	validation-rmse:8.02743
# [11]	validation-rmse:7.96601
# [12]	validation-rmse:7.89609
# [13]	validation-rmse:7.84209
# [14]	validation-rmse:7.79532
# [15]	validation-rmse:7.77007
# [16]	validation-rmse:7.74577
# [17]	validation-rmse:7.71932
# [18]	validation-rmse:7.67236
# [19]	validation-rmse:7.66303
# [20]	validation-rmse:7.63391
# [21]	validation-rmse:7.60215
# [22]	validation-rmse:7.58748
# [23]	validation-rmse:7.56474
# [24]	validation-rmse:7.55627
# [25]	validation-rmse:7.55345
# [26]	validation-rmse:7.54478
# [27]	validation-rmse:7.53962
# [28]	validation-rmse:7.53729
# [29]	validation-rmse:7.53822
# [30]	validation-rmse:7.52944
# [31]	validation-rmse:7.52623
# [32]	validation-rmse:7.52438
# [33]	validation-rmse:7.52300
# [34]	validation-rmse:7.52130
# [35]	validation-rmse:7.52312
# [36]	validation-rmse:7.52025
# [37]	validation-rmse:7.51131
# [38]	validation-rmse:7.50991
# [39]	validation-rmse:7.50751
# [40]	validation-rmse:7.50713
# [41]	validation-rmse:7.50566
# [42]	validation-rmse:7.50528
# [43]	validation-rmse:7.50393
# [44]	validation-rmse:7.50305
# [45]	validation-rmse:7.50043
# [46]	validation-rmse:7.49815
# [47]	validation-rmse:7.49807
# [48]	validation-rmse:7.49710
# [49]	validation-rmse:7.49580
# [50]	validation-rmse:7.49537
# [51]	validation-rmse:7.49701
# [52]	validation-rmse:7.49392
# [53]	validation-rmse:7.49241
# [54]	validation-rmse:7.49050
# [55]	validation-rmse:7.48932
# [56]	validation-rmse:7.48787
# [57]	validation-rmse:7.48696
# [58]	validation-rmse:7.48586
# [59]	validation-rmse:7.48494
# [60]	validation-rmse:7.48403
# [61]	validation-rmse:7.48238
# [62]	validation-rmse:7.48185
# [63]	validation-rmse:7.48014
# [64]	validation-rmse:7.47946
# [65]	validation-rmse:7.47673
# [66]	validation-rmse:7.47707
# [67]	validation-rmse:7.47596
# [68]	validation-rmse:7.47527
# [69]	validation-rmse:7.47363
# [70]	validation-rmse:7.47218
# [71]	validation-rmse:7.47102
# [72]	validation-rmse:7.47126
# [73]	validation-rmse:7.47059
# [74]	validation-rmse:7.46839
# [75]	validation-rmse:7.46748
# [76]	validation-rmse:7.46739
# [77]	validation-rmse:7.46673
# [78]	validation-rmse:7.46400
# [79]	validation-rmse:7.46391
# [80]	validation-rmse:7.46295
# [81]	validation-rmse:7.46131
# [82]	validation-rmse:7.46108
# [83]	validation-rmse:7.45986
# [84]	validation-rmse:7.45929
# [85]	validation-rmse:7.45905
# [86]	validation-rmse:7.45869
# [87]	validation-rmse:7.45858
# [88]	validation-rmse:7.45950
# [89]	validation-rmse:7.45835
# [90]	validation-rmse:7.45872
# [91]	validation-rmse:7.45694
# [92]	validation-rmse:7.45739
# [93]	validation-rmse:7.45698
# [94]	validation-rmse:7.45571
# [95]	validation-rmse:7.45574
# [96]	validation-rmse:7.45407
# [97]	validation-rmse:7.45330
# [98]	validation-rmse:7.45423
# [99]	validation-rmse:7.45339
# 2022/06/01 09:32:49 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %% [markdown]
# ## Model management

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "jana")

    mlflow.log_param("train-data-path", r"C:\Users\JC\projects\MLOps_Zoomcamp_2022\data\green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", r"C:\Users\JC\projects\MLOps_Zoomcamp_2022\data\green_tripdata_2021-01.parquet")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    # Save the model as an artifact
    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle/")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# c:\Users\JC\projects\MLOps_Zoomcamp_2022\module_2\module_2.ipynb Cell 24' in <cell line: 1>()
#      <a href='vscode-notebook-cell:/c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/module_2.ipynb#ch0000033?line=14'>15</a> mlflow.log_metric("rmse", rmse)
#      <a href='vscode-notebook-cell:/c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/module_2.ipynb#ch0000033?line=16'>17</a> # Save the model as an artifact
# ---> <a href='vscode-notebook-cell:/c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/module_2.ipynb#ch0000033?line=17'>18</a> mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle/")
#
# File c:\Users\JC\projects\MLOps_Zoomcamp_2022\module_2\.venv\lib\site-packages\mlflow\tracking\fluent.py:693, in log_artifact(local_path, artifact_path)
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/fluent.py?line=669'>670</a> """
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/fluent.py?line=670'>671</a> Log a local file or directory as an artifact of the currently active run. If no run is
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/fluent.py?line=671'>672</a> active, this method will create a new active run.
#    (...)
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/fluent.py?line=689'>690</a>         mlflow.log_artifact("features.txt")
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/fluent.py?line=690'>691</a> """
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/fluent.py?line=691'>692</a> run_id = _get_or_start_run().info.run_id
# --> <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/fluent.py?line=692'>693</a> MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File c:\Users\JC\projects\MLOps_Zoomcamp_2022\module_2\.venv\lib\site-packages\mlflow\tracking\client.py:955, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/client.py?line=919'>920</a> def log_artifact(self, run_id, local_path, artifact_path=None) -> None:
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/client.py?line=920'>921</a>     """
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/client.py?line=921'>922</a>     Write a local file or directory to the remote ``artifact_uri``.
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/client.py?line=922'>923</a>
#    (...)
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/client.py?line=952'>953</a>         is_dir: False
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/client.py?line=953'>954</a>     """
# --> <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/client.py?line=954'>955</a>     self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File c:\Users\JC\projects\MLOps_Zoomcamp_2022\module_2\.venv\lib\site-packages\mlflow\tracking\_tracking_service\client.py:337, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/_tracking_service/client.py?line=334'>335</a>     artifact_repo.log_artifacts(local_path, path_name)
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/_tracking_service/client.py?line=335'>336</a> else:
# --> <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/tracking/_tracking_service/client.py?line=336'>337</a>     artifact_repo.log_artifact(local_path, artifact_path)
#
# File c:\Users\JC\projects\MLOps_Zoomcamp_2022\module_2\.venv\lib\site-packages\mlflow\store\artifact\local_artifact_repo.py:27, in LocalArtifactRepository.log_artifact(self, local_file, artifact_path)
#      <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/local_artifact_repo.py?line=25'>26</a> def log_artifact(self, local_file, artifact_path=None):
# ---> <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/local_artifact_repo.py?line=26'>27</a>     verify_artifact_path(artifact_path)
#      <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/local_artifact_repo.py?line=27'>28</a>     # NOTE: The artifact_path is expected to be in posix format.
#      <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/local_artifact_repo.py?line=28'>29</a>     # Posix paths work fine on windows but just in case we normalize it here.
#      <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/local_artifact_repo.py?line=29'>30</a>     if artifact_path:
#
# File c:\Users\JC\projects\MLOps_Zoomcamp_2022\module_2\.venv\lib\site-packages\mlflow\store\artifact\artifact_repo.py:300, in verify_artifact_path(artifact_path)
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/artifact_repo.py?line=297'>298</a> def verify_artifact_path(artifact_path):
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/artifact_repo.py?line=298'>299</a>     if artifact_path and path_not_unique(artifact_path):
# --> <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/artifact_repo.py?line=299'>300</a>         raise MlflowException(
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/artifact_repo.py?line=300'>301</a>             "Invalid artifact path: '%s'. %s" % (artifact_path, bad_path_message(artifact_path))
#     <a href='file:///c%3A/Users/JC/projects/MLOps_Zoomcamp_2022/module_2/.venv/lib/site-packages/mlflow/store/artifact/artifact_repo.py?line=301'>302</a>         )
#
# MlflowException: Invalid artifact path: 'models_pickle/'. Names may be treated as files in certain cases, and must not resolve to other names when treated as such. This name would resolve to 'models_pickle'

# %%
# Save the model as an artifact
mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="model/pickle")
